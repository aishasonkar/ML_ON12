# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/aishasonkar/ML_ON12/blob/master/5th_assignment.ipynb)

# %%
import pandas as pd
import numpy as np

# %%
#Q1 upload dataframe
df=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
df.shape
# Out:
# (366, 24)

# %%
df.size
# Out:
# 8784

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df.isnull()
# Out:
#       Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    False     False    False    False     False        False     False
# 1    False     False    False    False     False        False     False
# 2    False     False    False    False     False        False     False
# 3    False     False    False    False     False        False     False
# 4    False     False    False    False     False        False     False
# 5    False     False    False    False     False        False     False
# 6    False     False    False    False     False        False     False
# 7    False     False    False    False     False        False     False
# 8    False     False    False    False     False        False     False
# 9    False     False    False    False     False        False     False
# 10   False     False    False    False     False        False     False
# 11   False     False    False    False     False        False     False
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df.WindDir9am
# Out:
# 0       SW
# 1        E
# 2        N
# 3      WNW
# 4      SSE
# 5       SE
# 6       SE
# 7       SE
# 8        E
# 9        S
# 10      SE
# 11       E
# 12       S
# 13     WNW
# 14       S
# 15      SE
# 16     WSW
# 17      SW
# 18     NNE
# 19     NNW
# 20       N
# 21     ENE
# 22       S
# 23     WSW
# 24     SSE
# 25       E
# 26       E
# 27       S
# 28      SE
# 29     SSW
#       ...
# 336    NNW
# 337     NW
# 338    NNW
# 339    ENE
# 340      N
# 341    NNW
# 342    NNE
# 343      S
# 344    NNW
# 345    SSW
# 346    ENE
# 347     NE
# 348    NNE
# 349    SSE
# 350     SW
# 351    NaN
# 352      N
# 353      W
# 354     SE
# 355      S
# 356      S
# 357    SSE
# 358    SSE
# 359      N
# 360    NaN
# 361    SSE
# 362    NNW
# 363    ENE
# 364    SSW
# 365     NW
# Name: WindDir9am, Length: 366, dtype: object

# %%
#remove missing  value
df=df[~df['WindDir9am'].isnull()]

# %%
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
df.shape
# Out:
# (335, 24)

# %%
df.WindSpeed9am
# Out:
# 0       6.0
# 1       4.0
# 2       6.0
# 3      30.0
# 4      20.0
# 5      20.0
# 6      19.0
# 7      11.0
# 8      19.0
# 9       7.0
# 10      6.0
# 11      2.0
# 12      6.0
# 13      7.0
# 14      6.0
# 15      7.0
# 16      6.0
# 17      6.0
# 18      4.0
# 19      2.0
# 20      2.0
# 21      6.0
# 22     13.0
# 23      6.0
# 24      9.0
# 25      6.0
# 26     20.0
# 27      6.0
# 28      7.0
# 29      6.0
#        ...
# 334     6.0
# 335     6.0
# 336    15.0
# 337    31.0
# 338    20.0
# 339     7.0
# 340    24.0
# 341    11.0
# 342     2.0
# 343     2.0
# 344     6.0
# 345     2.0
# 346     4.0
# 347     6.0
# 348     7.0
# 349     4.0
# 350     2.0
# 352     4.0
# 353     2.0
# 354     6.0
# 355    11.0
# 356    35.0
# 357    26.0
# 358     2.0
# 359     4.0
# 361     7.0
# 362     2.0
# 363    11.0
# 364     6.0
# 365    31.0
# Name: WindSpeed9am, Length: 335, dtype: float64

# %%
df.WindSpeed3pm
# Out:
# 0      20
# 1      17
# 2       6
# 3      24
# 4      28
# 5      24
# 6      26
# 7      24
# 8      17
# 9       6
# 10      9
# 11     15
# 12      7
# 13     20
# 14     20
# 15      9
# 16     19
# 17     11
# 18     17
# 19     13
# 20     31
# 21     11
# 22     13
# 23      9
# 24     15
# 25     22
# 26     17
# 27     11
# 28     17
# 29      6
#        ..
# 334    28
# 335    30
# 336    28
# 337    41
# 338    19
# 339    19
# 340    33
# 341    28
# 342    26
# 343     9
# 344    19
# 345    17
# 346    11
# 347    33
# 348    24
# 349     7
# 350     9
# 352    20
# 353    26
# 354    31
# 355    11
# 356    37
# 357    15
# 358    17
# 359    19
# 361    50
# 362    19
# 363     9
# 364    28
# 365    35
# Name: WindSpeed3pm, Length: 335, dtype: int64

# %%
df=df[~df['WindSpeed9am'].isnull()]

# %%
df=df[~df['WindSpeed9am'].isnull()]

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         3
# WindGustDir      3
# WindGustSpeed    2
# WindDir9am       0
# WindDir3pm       1
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df=df[~df['WindSpeed3pm'].isnull()]

# %%
df=df[~df['WindGustSpeed'].isnull()]

# %%
df=df[~df['WindGustDir'].isnull()]

# %%
df=df[~df['Sunshine'].isnull()]

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df=df[~df['WindDir3pm'].isnull()]

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.dropna().shape
# Out:
# (328, 24)

# %%
#3.Q  again import data
data=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
data
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
#fill missing value with mean
data['WindGustSpeed']=data['WindGustSpeed'].fillna(data['WindGustSpeed'].mean())

# %%
data['WindGustSpeed'].mean()
# Out:
# 39.84065934065934

# %%
data.WindDir9am.replace(['N'],['n'])
# Out:
# 0       SW
# 1        E
# 2        n
# 3      WNW
# 4      SSE
# 5       SE
# 6       SE
# 7       SE
# 8        E
# 9        S
# 10      SE
# 11       E
# 12       S
# 13     WNW
# 14       S
# 15      SE
# 16     WSW
# 17      SW
# 18     NNE
# 19     NNW
# 20       n
# 21     ENE
# 22       S
# 23     WSW
# 24     SSE
# 25       E
# 26       E
# 27       S
# 28      SE
# 29     SSW
#       ...
# 336    NNW
# 337     NW
# 338    NNW
# 339    ENE
# 340      n
# 341    NNW
# 342    NNE
# 343      S
# 344    NNW
# 345    SSW
# 346    ENE
# 347     NE
# 348    NNE
# 349    SSE
# 350     SW
# 351    NaN
# 352      n
# 353      W
# 354     SE
# 355      S
# 356      S
# 357    SSE
# 358    SSE
# 359      n
# 360    NaN
# 361    SSE
# 362    NNW
# 363    ENE
# 364    SSW
# 365     NW
# Name: WindDir9am, Length: 366, dtype: object

# %%
data
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
data.fillna('fillinga').isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64
